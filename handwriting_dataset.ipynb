# %%
import numpy as np

# %%
ScriptX=np.loadtxt("Handwriting_data/ScriptX.csv", skiprows=1, delimiter=',',usecols=range(1,21))
ScriptY=np.loadtxt("Handwriting_data/ScriptY.csv", skiprows=1, delimiter=',',usecols=range(1,21))
time=np.loadtxt("Handwriting_data/time.csv", skiprows=1, delimiter=',',usecols=1)
Data=np.dstack((ScriptX,ScriptY))
ScriptY.shape
# Out:
# (1401, 20)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10,7))
plt.plot(ScriptX[:,0], ScriptY[:,0])
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.plot(time, ScriptX[:,0])
plt.xlabel("time")
plt.ylabel("X")

plt.subplot(1, 2, 2)
plt.plot(time, ScriptY[:,0])
plt.xlabel("time")
plt.ylabel("Y")
plt.show()

# %%
Xdiff1=np.diff(ScriptX,axis=0)
Ydiff1=np.diff(ScriptY,axis=0)
Xdiff2=np.diff(ScriptX, n=2,axis=0)
Ydiff2=np.diff(ScriptY, n=2,axis=0)

# %%
plt.figure(figsize=(12,10))
plt.subplot(2, 1, 1)
plt.plot(Xdiff1[:,2],linewidth=0.2)
plt.xlabel("time")
plt.ylabel("X")

plt.subplot(2, 1, 2)
plt.plot( Xdiff2[:,2],linewidth=0.2)
plt.xlabel("time")
plt.ylabel("Y")
plt.show()
